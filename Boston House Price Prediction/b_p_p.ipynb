# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
a = pd.read_csv("Boston_Train.csv")
b = pd.read_csv("Boston_Test.csv")
df = pd.concat([a,b])

# %%
df.drop(columns = ["Unnamed: 0"], axis = 0, inplace = True)

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
x = df.drop(columns = ["medv"])
y = df['medv']
corr = df.corr()
corr.shape
# Out:
# (14, 14)

# %%
# Plotting the heatmap of correlation between features
plt.figure(figsize=(10,10))
sns.heatmap(corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Linear Regression

# %%
# Splitting to training and testing data
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, Y_test = train_test_split(x,y, test_size = 0.3)

# %%
# Import library for Linear Regression
from sklearn.linear_model import LinearRegression

# Create a Linear regressor
lm = LinearRegression()

# Train the model using the training sets 
lm.fit(x_train, y_train)

# Model prediction on train data
y_pred = lm.predict(x_train)

# %%
metrics.r2_score(y_train, y_pred)
# Out:
# 0.7600717972403788

# %%
# Predicting Test data with the model
y_test_pred = lm.predict(X_test)
metrics.r2_score(Y_test, y_test_pred)
# Out:
# 0.683769817849142

# %%
#plt.scatter(y_train, y_pred)
#sns.regplot(y_train, y_pred, color = 'red')
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
sns.regplot(x = y_train, y = y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.show()

# %% [markdown]
# ### Random Forest Regressor

# %%
# Import Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
reg = RandomForestRegressor()

# Train the model using the training sets 
reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Model prediction on train data
y_pred = reg.predict(x_train)
metrics.r2_score(y_train, y_pred)
# Out:
# 0.9755344058288471

# %%
# Predicting Test data with the model
y_test_pred = reg.predict(X_test)
metrics.r2_score(Y_test, y_test_pred)
# Out:
# 0.8935023678332179

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
sns.regplot(x = y_train, y = y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.show()

# %% [markdown]
# ### Gradient Boost Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# %%
reg = GradientBoostingRegressor()
reg.fit(x_train, y_train)

# Model prediction on train data
y_pred = reg.predict(x_train)

# %%
metrics.r2_score(y_train, y_pred)
# Out:
# 0.979971975075636

# %%
#Predicting Test data with the model
y_test_pred = reg.predict(X_test)
metrics.r2_score(Y_test, y_test_pred)
# Out:
# 0.915091896237443

# %%
# Visualizing the differences between actual prices and predicted values
#plt.scatter(y_train, y_pred)
#plt.scatter(Y_test, y_test_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
sns.regplot(x = y_train, y = y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.show()

# %% [markdown]
# ### XGBoost Regressor

# %%
# Import XGBoost Regressor
from xgboost import XGBRegressor

#Create a XGBoost Regressor
reg = XGBRegressor()

# Train the model using the training sets 
reg.fit(x_train, y_train)

# Model prediction on train data
y_pred = reg.predict(x_train)

# %%
metrics.r2_score(y_train, y_pred)
# Out:
# 0.9999955097892264

# %%
#Predicting Test data with the model
y_test_pred = reg.predict(X_test)
metrics.r2_score(Y_test, y_test_pred)
# Out:
# 0.8627489883092276

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)  #plt.scatter(Y_test, y_test_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
sns.regplot(x = y_train, y = y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.show()

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.scatter(Y_test, y_test_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
sns.regplot(x = y_train, y = y_pred, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.show()
